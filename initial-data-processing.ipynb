# %% [markdown]
# # Medical Cost Inital Analysis
# In this page of the notebook, I have imported medical cost data from Kaggle and preform the first steps of exploratory data analysis.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
def configure_plots():
    '''Configures plots by making some quality of life adjustments'''
    for _ in range(2):
        plt.rcParams['figure.figsize'] = [16, 9]
        plt.rcParams['axes.titlesize'] = 20
        plt.rcParams['axes.labelsize'] = 16
        plt.rcParams['xtick.labelsize'] = 14
        plt.rcParams['ytick.labelsize'] = 14
        plt.rcParams['lines.linewidth'] = 2

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
data = pd.read_csv("./archive (2)/medical_cost.csv")

# %%
data.head()
# Out:
#    Id  age     sex     bmi  children smoker     region      charges
# 0   1   19  female  27.900         0    yes  southwest  16884.92400
# 1   2   18    male  33.770         1     no  southeast   1725.55230
# 2   3   28    male  33.000         3     no  southeast   4449.46200
# 3   4   33    male  22.705         0     no  northwest  21984.47061
# 4   5   32    male  28.880         0     no  northwest   3866.85520

# %%
data.shape
# Out:
# (1338, 8)

# %%
data.columns
# Out:
# Index(['Id', 'age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# #### Inital Notes About Data
# The categories included in the dataset are ID (which replaces the patients name), age, sex, bmi (body mass index), children (the number of children the patient has), smoker, region (seperated by northeast, northwest, southeast, and southwest), and charges (the medical charges incurred by the patient).
# There are 1338 data points in the set before processing.

# %% [markdown]
# #### Exploratory Graphs and Visualizations

# %%
#Age vs Charges scatterplots
sns.scatterplot(x=data['age'], y=data['charges'], alpha = 0.5)
plt.title("Age vs Charges")
plt.xlabel("Age (years)")
plt.ylabel("Charges ($)")
# Out:
# Text(0, 0.5, 'Charges ($)')

# %%
#Box plot bewteen sex and charges
sns.boxplot(x=data['sex'], y=data['charges'], palette = ['#CBAACB', '#B2DFDB'])
plt.title('Box Plot of Charges by Sex')
plt.xlabel('Sex')
plt.ylabel('Charges')
# Out:
# Text(0, 0.5, 'Charges')

# %%
#Box plot bewteen regions and charges
sns.boxplot(x=data['region'], y=data['charges'], palette = 'pastel')
plt.title('Box Plot of Charges by Region')
plt.xlabel('Region')
plt.ylabel('Charges')
# Out:
# Text(0, 0.5, 'Charges')

# %%
#Scatterplot plot using BMI and Charges
sns.scatterplot(x=data['bmi'], y=data['charges'])
plt.title("BMI vs Charges")
plt.xlabel("BMI")
plt.ylabel("Charges ($)")
# Out:
# Text(0, 0.5, 'Charges ($)')

# %%
#Boxplot showing charges by smoking status
sns.boxplot(x=data['smoker'], y=data['charges'], palette = ['#FF6961', '#AEC6CF'])
plt.title('Box Plot of Charges by Smoker or Non-Smoker')
plt.xlabel('Region')
plt.ylabel('Charges')
# Out:
# Text(0, 0.5, 'Charges')

# %%
#Boxplot showing charges by number of children
sns.boxplot(x=data['children'], y=data['charges'], palette = 'pastel')
plt.title('Box Plot of Charges by Number of Children')
plt.xlabel('Number of Children')
plt.ylabel('Charges')
# Out:
# Text(0, 0.5, 'Charges')

# %% [markdown]
# #### Notes About Data After Visualizations
# Charges by Age: The common trend seems to be that as age increases, medical costs increase. There also seems to be three "categories" of sorts ranging between differnet charge amounts, but all of them follow the trend.
#
# Charges by Sex: The median for both men and women are very similar to each other, but the men's third quartile is greater than the women's third quartile.
#
# Charges by Region: The medians for each region are relatively the same, with the southeast and northeast medians being slightly higher. The third quartiles have more variety, again with the southeast and northeast medians being slightly higher than the othet two regions.
#
# Charges by BMI: The common trend seems to be that as BMI increases, medical costs increase. There seem to be some outliers around the graph that are unusually high for a low BMI or unusually low for a high BMI.
#
# Charges by Smoking Status: The medians for smoker and non-smoker are vastly different, with the smoker median being much higher than the non-smoker median. There also seems to be little to no outliers in the smoker data.
#
# Charges by Number of Children: The medians for each number of children are relatively the same, with zero, three, and four amounts being closer together and higher. The third quartiles have more variety, with the two and three amounts being the highest.

# %% [markdown]
# ### Next Steps
# After these inital graphs and findings, I hope to look at different models that can estimate potenial cost given age, sex, region, BMI, smoking status, and number of children. Then I will compare each model to find the best predictor.
